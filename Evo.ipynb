# %% [markdown]
# <a href="https://colab.research.google.com/github/RuchchaSD/Useful_files/blob/main/Evo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline
from IPython.display import Image

# %%
# !pip install evo --upgrade
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.4/145.4 kB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.8/131.8 kB 8.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 2.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 30.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.7/117.7 kB 7.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 739.1/739.1 kB 33.1 MB/s eta 0:00:00
# ...

# %%
import numpy as np

file_path = "/content/CameraTrajectory_board.txt"
data = np.loadtxt(file_path)

# Verify if the data has correct KITTI format (should have 7 columns)
print(data.shape)
# Out:
# (3681, 8)

# %% [markdown]
# !evo_traj tum \{esitmate.txt} --ref {ground truth} -va --plot --plot_mode xz

# %%
# !evo_traj tum /content/CameraTrajectory_board.txt --ref /content/output_file.txt -va --plot --save_plot traj_plot.png --plot_mode xz
# Out:
# --------------------------------------------------------------------------------
# Loaded 3681 stamps and poses from: /content/CameraTrajectory_board.txt
# Loaded 3638 stamps and poses from: /content/output_file.txt
# --------------------------------------------------------------------------------
# Found 2547 of max. 3638 possible matching timestamps between...
# 	reference
# and:	/content/CameraTrajectory_board.txt
# ..with max. time diff.: 0.01 (s) and time offset: 0.0 (s).
# --------------------------------------------------------------------------------
# Aligning /content/CameraTrajectory_board.txt to reference.
# Aligning using Umeyama's method...
# Rotation of alignment:
# [[ 0.33890308  0.28328558 -0.89715884]
#  [ 0.9400875  -0.13962094  0.31103294]
#  [-0.03715101 -0.94881783 -0.3136312 ]]
# Translation of alignment:
# [2.76156098 1.56898488 0.40596425]
# Scale correction: 1.0
# --------------------------------------------------------------------------------
# ...

# %%
# !evo_ape tum /content/CameraTrajectory_board.txt /content/output_file.txt -va --plot --save_plot ape_plot.png --plot_mode xz
Image("/content/ape_plot_map.png")
Image("/content/ape_plot_map.png")
# Out:
# --------------------------------------------------------------------------------
# Loaded 3681 stamps and poses from: /content/CameraTrajectory_board.txt
# Loaded 3638 stamps and poses from: /content/output_file.txt
# --------------------------------------------------------------------------------
# Synchronizing trajectories...
# Found 2547 of max. 3638 possible matching timestamps between...
# 	/content/CameraTrajectory_board.txt
# and:	/content/output_file.txt
# ..with max. time diff.: 0.01 (s) and time offset: 0.0 (s).
# --------------------------------------------------------------------------------
# Aligning using Umeyama's method...
# Rotation of alignment:
# [[ 0.33890308  0.9400875  -0.03715101]
#  [ 0.28328558 -0.13962094 -0.94881783]
#  [-0.89715884  0.31103294 -0.3136312 ]]
# Translation of alignment:
# [-2.39580262 -0.17806114  2.11687591]
# Scale correction: 1.0
# --------------------------------------------------------------------------------
# ...

# %%
# !evo_rpe tum /content/CameraTrajectory_board.txt /content/output_file.txt -va --plot  --save_plot rpe_plot.png --plot_mode xz
Image("/content/rpe_plot_map.png")
Image("/content/rpe_plot_map.png")
# Out:
# --------------------------------------------------------------------------------
# Loaded 3681 stamps and poses from: /content/CameraTrajectory_board.txt
# Loaded 3638 stamps and poses from: /content/output_file.txt
# --------------------------------------------------------------------------------
# Synchronizing trajectories...
# Found 2547 of max. 3638 possible matching timestamps between...
# 	/content/CameraTrajectory_board.txt
# and:	/content/output_file.txt
# ..with max. time diff.: 0.01 (s) and time offset: 0.0 (s).
# --------------------------------------------------------------------------------
# Aligning using Umeyama's method...
# Rotation of alignment:
# [[ 0.33890308  0.9400875  -0.03715101]
#  [ 0.28328558 -0.13962094 -0.94881783]
#  [-0.89715884  0.31103294 -0.3136312 ]]
# Translation of alignment:
# [-2.39580262 -0.17806114  2.11687591]
# Scale correction: 1.0
# --------------------------------------------------------------------------------
# ...
